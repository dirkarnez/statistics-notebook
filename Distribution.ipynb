# %%
import sys
# !conda install --yes --prefix {sys.prefix} numpy

import sys
# !conda install --yes --prefix {sys.prefix} matplotlib

import sys
# !conda install --yes --prefix {sys.prefix} seaborn
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cycler-0.10.0              |             py_2           9 KB  conda-forge
#     dbus-1.13.6                |       hfdff14a_1         585 KB  conda-forge
#     expat-2.2.9                |       he1b5a44_2         191 KB  conda-forge
#     fontconfig-2.13.1          |    h736d332_1003         319 KB  conda-forge
#     freetype-2.10.4            |       h7ca028e_0         912 KB  conda-forge
#     gettext-0.19.8.1           |    h0b5b191_1005         3.6 MB  conda-forge
#     glib-2.66.4                |       hcd2ae1e_1         494 KB  conda-forge
#     gst-plugins-base-1.14.5    |       h0935bb2_2         6.8 MB  conda-forge
#     gstreamer-1.18.2           |       ha23517c_0         2.0 MB  conda-forge
#     jpeg-9d                    |       h36c2ea0_0         264 KB  conda-forge
#     kiwisolver-1.3.1           |   py38h82cb98a_0          86 KB  conda-forge
#     lcms2-2.11                 |       hcbb858e_1         434 KB  conda-forge
#     libclang-11.0.0            |default_ha5c780c_2        18.1 MB  conda-forge
#     libevent-2.1.10            |       hcdb4288_3         1.1 MB  conda-forge
#     libglib-2.66.4             |       h164308a_1         3.0 MB  conda-forge
#     libiconv-1.16              |       h516909a_0         1.4 MB  conda-forge
#     libllvm11-11.0.0           |       he513fc3_0        28.4 MB  conda-forge
#     libpng-1.6.37              |       h21135ba_2         306 KB  conda-forge
#     libpq-12.3                 |       h255efa7_3         2.6 MB  conda-forge
#     libtiff-4.2.0              |       hdc55705_0         633 KB  conda-forge
#     libuuid-2.32.1             |    h7f98852_1000          28 KB  conda-forge
#     libwebp-base-1.1.0         |       h36c2ea0_3         864 KB  conda-forge
#     libxcb-1.13                |    h14c3975_1002         396 KB  conda-forge
#     libxkbcommon-1.0.3         |       he3ba5ed_0         581 KB  conda-forge
#     libxml2-2.9.10             |       h72842e0_3         1.3 MB  conda-forge
#     lz4-c-1.9.2                |       he1b5a44_3         203 KB  conda-forge
#     matplotlib-3.3.3           |   py38h578d9bd_0           6 KB  conda-forge
#     matplotlib-base-3.3.3      |   py38h5c7f4ab_0         6.7 MB  conda-forge
#     mysql-common-8.0.22        |       ha770c72_1         1.5 MB  conda-forge
#     mysql-libs-8.0.22          |       h1fd7589_1         1.7 MB  conda-forge
#     nspr-4.29                  |       he1b5a44_1         232 KB  conda-forge
#     nss-3.60                   |       hb5efdd6_0         2.1 MB  conda-forge
#     olefile-0.46               |     pyh9f0ad1d_1          32 KB  conda-forge
#     pcre-8.44                  |       he1b5a44_0         261 KB  conda-forge
#     pillow-8.0.1               |   py38h70fbd49_0         678 KB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     pyqt-5.12.3                |   py38h578d9bd_6          21 KB  conda-forge
#     pyqt-impl-5.12.3           |   py38h7400c14_6         5.9 MB  conda-forge
#     pyqt5-sip-4.19.18          |   py38h709712a_6         310 KB  conda-forge
#     pyqtchart-5.12             |   py38h7400c14_6         257 KB  conda-forge
#     pyqtwebengine-5.12.1       |   py38h7400c14_6         175 KB  conda-forge
#     qt-5.12.9                  |       h9d6b050_2        99.5 MB  conda-forge
#     xorg-libxau-1.0.9          |       h14c3975_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h516909a_0          18 KB  conda-forge
#     zstd-1.4.5                 |       h6597ccf_2         712 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       194.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   cycler             conda-forge/noarch::cycler-0.10.0-py_2
#   dbus               conda-forge/linux-64::dbus-1.13.6-hfdff14a_1
#   expat              conda-forge/linux-64::expat-2.2.9-he1b5a44_2
#   fontconfig         conda-forge/linux-64::fontconfig-2.13.1-h736d332_1003
#   freetype           conda-forge/linux-64::freetype-2.10.4-h7ca028e_0
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-h0b5b191_1005
#   glib               conda-forge/linux-64::glib-2.66.4-hcd2ae1e_1
#   gst-plugins-base   conda-forge/linux-64::gst-plugins-base-1.14.5-h0935bb2_2
#   gstreamer          conda-forge/linux-64::gstreamer-1.18.2-ha23517c_0
#   jpeg               conda-forge/linux-64::jpeg-9d-h36c2ea0_0
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.3.1-py38h82cb98a_0
#   lcms2              conda-forge/linux-64::lcms2-2.11-hcbb858e_1
#   libclang           conda-forge/linux-64::libclang-11.0.0-default_ha5c780c_2
#   libevent           conda-forge/linux-64::libevent-2.1.10-hcdb4288_3
#   libglib            conda-forge/linux-64::libglib-2.66.4-h164308a_1
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   libllvm11          conda-forge/linux-64::libllvm11-11.0.0-he513fc3_0
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libpq              conda-forge/linux-64::libpq-12.3-h255efa7_3
#   libtiff            conda-forge/linux-64::libtiff-4.2.0-hdc55705_0
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h7f98852_1000
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.1.0-h36c2ea0_3
#   libxcb             conda-forge/linux-64::libxcb-1.13-h14c3975_1002
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.0.3-he3ba5ed_0
#   libxml2            conda-forge/linux-64::libxml2-2.9.10-h72842e0_3
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.2-he1b5a44_3
#   matplotlib         conda-forge/linux-64::matplotlib-3.3.3-py38h578d9bd_0
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.3.3-py38h5c7f4ab_0
#   mysql-common       conda-forge/linux-64::mysql-common-8.0.22-ha770c72_1
#   mysql-libs         conda-forge/linux-64::mysql-libs-8.0.22-h1fd7589_1
#   nspr               conda-forge/linux-64::nspr-4.29-he1b5a44_1
#   nss                conda-forge/linux-64::nss-3.60-hb5efdd6_0
#   olefile            conda-forge/noarch::olefile-0.46-pyh9f0ad1d_1
#   pcre               conda-forge/linux-64::pcre-8.44-he1b5a44_0
#   pillow             conda-forge/linux-64::pillow-8.0.1-py38h70fbd49_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pyqt               conda-forge/linux-64::pyqt-5.12.3-py38h578d9bd_6
#   pyqt-impl          conda-forge/linux-64::pyqt-impl-5.12.3-py38h7400c14_6
#   pyqt5-sip          conda-forge/linux-64::pyqt5-sip-4.19.18-py38h709712a_6
#   pyqtchart          conda-forge/linux-64::pyqtchart-5.12-py38h7400c14_6
#   pyqtwebengine      conda-forge/linux-64::pyqtwebengine-5.12.1-py38h7400c14_6
#   qt                 conda-forge/linux-64::qt-5.12.9-h9d6b050_2
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h14c3975_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h516909a_0
#   zstd               conda-forge/linux-64::zstd-1.4.5-h6597ccf_2
#
#
#
# Downloading and Extracting Packages
# lcms2-2.11           | 434 KB    | ##################################### | 100%
# kiwisolver-1.3.1     | 86 KB     | ##################################### | 100%
# freetype-2.10.4      | 912 KB    | ##################################### | 100%
# matplotlib-base-3.3. | 6.7 MB    | ##################################### | 100%
# libevent-2.1.10      | 1.1 MB    | ##################################### | 100%
# libllvm11-11.0.0     | 28.4 MB   | ##################################### | 100%
# libuuid-2.32.1       | 28 KB     | ##################################### | 100%
# gettext-0.19.8.1     | 3.6 MB    | ##################################### | 100%
# libglib-2.66.4       | 3.0 MB    | ##################################### | 100%
# zstd-1.4.5           | 712 KB    | ##################################### | 100%
# libxkbcommon-1.0.3   | 581 KB    | ##################################### | 100%
# olefile-0.46         | 32 KB     | ##################################### | 100%
# pthread-stubs-0.4    | 5 KB      | ##################################### | 100%
# pyqt-5.12.3          | 21 KB     | ##################################### | 100%
# mysql-common-8.0.22  | 1.5 MB    | ##################################### | 100%
# libtiff-4.2.0        | 633 KB    | ##################################### | 100%
# gst-plugins-base-1.1 | 6.8 MB    | ##################################### | 100%
# pyqt5-sip-4.19.18    | 310 KB    | ##################################### | 100%
# gstreamer-1.18.2     | 2.0 MB    | ##################################### | 100%
# pyqt-impl-5.12.3     | 5.9 MB    | ##################################### | 100%
# pcre-8.44            | 261 KB    | ##################################### | 100%
# jpeg-9d              | 264 KB    | ##################################### | 100%
# nss-3.60             | 2.1 MB    | ##################################### | 100%
# libwebp-base-1.1.0   | 864 KB    | ##################################### | 100%
# pyqtwebengine-5.12.1 | 175 KB    | ##################################### | 100%
# fontconfig-2.13.1    | 319 KB    | ##################################### | 100%
# libclang-11.0.0      | 18.1 MB   | ##################################### | 100%
# cycler-0.10.0        | 9 KB      | ##################################### | 100%
# libiconv-1.16        | 1.4 MB    | ##################################### | 100%
# dbus-1.13.6          | 585 KB    | ##################################### | 100%
# qt-5.12.9            | 99.5 MB   | ##################################### | 100%
# xorg-libxau-1.0.9    | 13 KB     | ##################################### | 100%
# matplotlib-3.3.3     | 6 KB      | ##################################### | 100%
# mysql-libs-8.0.22    | 1.7 MB    | ##################################### | 100%
# glib-2.66.4          | 494 KB    | ##################################### | 100%
# pillow-8.0.1         | 678 KB    | ##################################### | 100%
# libpng-1.6.37        | 306 KB    | ##################################### | 100%
# libpq-12.3           | 2.6 MB    | ##################################### | 100%
# expat-2.2.9          | 191 KB    | ##################################### | 100%
# lz4-c-1.9.2          | 203 KB    | ##################################### | 100%
# libxml2-2.9.10       | 1.3 MB    | ##################################### | 100%
# xorg-libxdmcp-1.1.3  | 18 KB     | ##################################### | 100%
# libxcb-1.13          | 396 KB    | ##################################### | 100%
# pyqtchart-5.12       | 257 KB    | ##################################### | 100%
# nspr-4.29            | 232 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-1.1.5               |   py38h51da96c_0        11.5 MB  conda-forge
#     patsy-0.5.1                |             py_0         187 KB  conda-forge
#     pytz-2020.4                |     pyhd8ed1ab_0         229 KB  conda-forge
#     scipy-1.5.3                |   py38hb2138dd_0        19.2 MB  conda-forge
#     seaborn-0.11.1             |       ha770c72_0           4 KB  conda-forge
#     seaborn-base-0.11.1        |     pyhd8ed1ab_0         218 KB  conda-forge
#     statsmodels-0.12.1         |   py38h0b5ebd8_1        11.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        42.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas             conda-forge/linux-64::pandas-1.1.5-py38h51da96c_0
#   patsy              conda-forge/noarch::patsy-0.5.1-py_0
#   pytz               conda-forge/noarch::pytz-2020.4-pyhd8ed1ab_0
#   scipy              conda-forge/linux-64::scipy-1.5.3-py38hb2138dd_0
#   seaborn            conda-forge/linux-64::seaborn-0.11.1-ha770c72_0
#   seaborn-base       conda-forge/noarch::seaborn-base-0.11.1-pyhd8ed1ab_0
#   statsmodels        conda-forge/linux-64::statsmodels-0.12.1-py38h0b5ebd8_1
#
#
#
# Downloading and Extracting Packages
# scipy-1.5.3          | 19.2 MB   | ##################################### | 100%
# seaborn-base-0.11.1  | 218 KB    | ##################################### | 100%
# pytz-2020.4          | 229 KB    | ##################################### | 100%
# patsy-0.5.1          | 187 KB    | ##################################### | 100%
# pandas-1.1.5         | 11.5 MB   | ##################################### | 100%
# seaborn-0.11.1       | 4 KB      | ##################################### | 100%
# statsmodels-0.12.1   | 11.1 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.standard_normal(8000), kind="kde", bw_adjust=2)

plt.show()
